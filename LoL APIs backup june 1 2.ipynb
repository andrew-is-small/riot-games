# %% [markdown]
# # Just gonging around with Riot Games APIs
#
# https://developer.riotgames.com/
#
# ok so summoner-v4 -> summoner name. id is encrypted id then use that in API below

# %%
import requests
import json

# %%
#Enter these in
sumName = 'NongKrekAcid'
apiKey = 'RGAPI-bc29a744-4f21-41dd-b4d1-bd8f79261abd'

# %%
sumInfo = requests.get('https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + sumName + '?api_key=' + apiKey)
#Can also add params so like (URL, params = {'page'=2,'count':10})

# %%
print(sumInfo.ok)
if not sumInfo.ok:
    print(sumInfo.status_code)
# Out:
# True

# %%
sumInfoDict = sumInfo.json()
sumInfo.json()
# Out:
# {'id': 'QGt1WY6sNA4sfOq55ivRrbFcNEU2K1JOXyVs8SjP-2GwVmDL',
#  'accountId': 'mZgOTJbtBRoHNEG2gFKY3zetLjma78Wj59AWY096kO8XQlnoGoc-mPZN',
#  'puuid': 'Hfr2lYWugol4WzwOzBAxAfEdaWG_Zse39lx4hNbTuBLzH3zR09af9fWx9rQo6A7OGxMjNav1QBcwuw',
#  'name': 'Nong Krek Acid',
#  'profileIconId': 18,
#  'revisionDate': 1575163733000,
#  'summonerLevel': 25}

# %%
sumId = sumInfoDict['id']
puuId = sumInfoDict['puuid']

# %%
masteryScore = requests.get('https://na1.api.riotgames.com/lol/champion-mastery/v4/scores/by-summoner/' + sumId + '?api_key=' + apiKey)
mastery = requests.get('https://na1.api.riotgames.com/lol/champion-mastery/v4/champion-masteries/by-summoner/' + sumId + '?api_key=' + apiKey)

# %%
score = masteryScore.json()
print(score)
# Out:
# 44

# %%
print(mastery.ok)
if not mastery.ok:
    print(mastery.status_code)
# Out:
# True

# %%
mscores = mastery.json()

# %%
mscores
# Out:
# [{'championId': 29,
#   'championLevel': 4,
#   'championPoints': 14387,
#   'lastPlayTime': 1575139049000,
#   'championPointsSinceLastLevel': 1787,
#   'championPointsUntilNextLevel': 7213,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'QGt1WY6sNA4sfOq55ivRrbFcNEU2K1JOXyVs8SjP-2GwVmDL'},
#  {'championId': 203,
#   'championLevel': 3,
#   'championPoints': 11883,
#   'lastPlayTime': 1571068772000,
#   'championPointsSinceLastLevel': 5883,
#   'championPointsUntilNextLevel': 717,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'QGt1WY6sNA4sfOq55ivRrbFcNEU2K1JOXyVs8SjP-2GwVmDL'},
#  {'championId': 28,
#   'championLevel': 2,
#   'championPoints': 4965,
#   'lastPlayTime': 1572662209000,
#   'championPointsSinceLastLevel': 3165,
#   'championPointsUntilNextLevel': 1035,
#   'chestGranted': False,
#   'tokensEarned': 0,
#   'summonerId': 'QGt1WY6sNA4sfOq55ivRrbFcNEU2K1JOXyVs8SjP-2GwVmDL'},
#  {'championId': 117,
#   'championLevel': 2,
# ...

# %%
type(mscores)
# Out:
# list

# %%
totalPoints = 0
for champion in mscores:
    totalPoints = totalPoints + champion['championPoints']
print(totalPoints)
# Out:
# 54294

# %% [markdown]
# # Closest to levelling up

# %%
ddragon = requests.get('http://ddragon.leagueoflegends.com/cdn/11.11.1/data/en_US/champion.json')

# %%
champData = ddragon.json()

# %%
champData['data']
# Out:
# {'Aatrox': {'version': '11.11.1',
#   'id': 'Aatrox',
#   'key': '266',
#   'name': 'Aatrox',
#   'title': 'the Darkin Blade',
#   'blurb': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...',
#   'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4},
#   'image': {'full': 'Aatrox.png',
#    'sprite': 'champion0.png',
#    'group': 'champion',
#    'x': 0,
#    'y': 0,
#    'w': 48,
#    'h': 48},
#   'tags': ['Fighter', 'Tank'],
#   'partype': 'Blood Well',
#   'stats': {'hp': 580,
#    'hpperlevel': 90,
#    'mp': 0,
#    'mpperlevel': 0,
#    'movespeed': 345,
#    'armor': 38,
#    'armorperlevel': 3.25,
#    'spellblock': 32,
#    'spellblockperlevel': 1.25,
#    'attackrange': 175,
#    'hpregen': 3,
#    'hpregenperlevel': 1,
#    'mpregen': 0,
# ...

# %%
NameToId = {}
for champ in champData['data']:
    NameToId[champData['data'][champ]['key']] = champData['data'][champ]['id']
print(NameToId)
# Out:
# {'266': 'Aatrox', '103': 'Ahri', '84': 'Akali', '12': 'Alistar', '32': 'Amumu', '34': 'Anivia', '1': 'Annie', '523': 'Aphelios', '22': 'Ashe', '136': 'AurelionSol', '268': 'Azir', '432': 'Bard', '53': 'Blitzcrank', '63': 'Brand', '201': 'Braum', '51': 'Caitlyn', '164': 'Camille', '69': 'Cassiopeia', '31': 'Chogath', '42': 'Corki', '122': 'Darius', '131': 'Diana', '119': 'Draven', '36': 'DrMundo', '245': 'Ekko', '60': 'Elise', '28': 'Evelynn', '81': 'Ezreal', '9': 'Fiddlesticks', '114': 'Fiora', '105': 'Fizz', '3': 'Galio', '41': 'Gangplank', '86': 'Garen', '150': 'Gnar', '79': 'Gragas', '104': 'Graves', '887': 'Gwen', '120': 'Hecarim', '74': 'Heimerdinger', '420': 'Illaoi', '39': 'Irelia', '427': 'Ivern', '40': 'Janna', '59': 'JarvanIV', '24': 'Jax', '126': 'Jayce', '202': 'Jhin', '222': 'Jinx', '145': 'Kaisa', '429': 'Kalista', '43': 'Karma', '30': 'Karthus', '38': 'Kassadin', '55': 'Katarina', '10': 'Kayle', '141': 'Kayn', '85': 'Kennen', '121': 'Khazix', '203': 'Kindred', '240': '
# ...

# %%
PUNLDic = []
for champion in mscores:
    if champion['championPointsUntilNextLevel'] != 0:
        name = NameToId[str(champion['championId'])]
        PUNLDic.append({'Name': name, 'punl': champion['championPointsUntilNextLevel']})
PUNLDic.sort(key=lambda x: x.get('punl'))
print(PUNLDic)
# Out:
# [{'Name': 'Thresh', 'punl': 348}, {'Name': 'Caitlyn', 'punl': 426}, {'Name': 'Draven', 'punl': 627}, {'Name': 'Kindred', 'punl': 717}, {'Name': 'Veigar', 'punl': 855}, {'Name': 'Rengar', 'punl': 930}, {'Name': 'Vayne', 'punl': 943}, {'Name': 'Singed', 'punl': 958}, {'Name': 'Ivern', 'punl': 1001}, {'Name': 'Evelynn', 'punl': 1035}, {'Name': 'Taliyah', 'punl': 1103}, {'Name': 'Fiddlesticks', 'punl': 1119}, {'Name': 'Annie', 'punl': 1135}, {'Name': 'Heimerdinger', 'punl': 1146}, {'Name': 'Tristana', 'punl': 1217}, {'Name': 'Kled', 'punl': 1223}, {'Name': 'Khazix', 'punl': 1250}, {'Name': 'Kaisa', 'punl': 1274}, {'Name': 'Teemo', 'punl': 1343}, {'Name': 'Karma', 'punl': 1547}, {'Name': 'DrMundo', 'punl': 1563}, {'Name': 'Shaco', 'punl': 1653}, {'Name': 'Poppy', 'punl': 1667}, {'Name': 'Xayah', 'punl': 1679}, {'Name': 'Jinx', 'punl': 1681}, {'Name': 'Jayce', 'punl': 1681}, {'Name': 'Camille', 'punl': 1682}, {'Name': 'Jhin', 'punl': 1682}, {'Name': 'Varus', 'punl': 1687}, {'Name': 'Rammus
# ...

# %%
for champ in PUNLDic:
    print(champ['Name'] + ": " + str(champ['punl']))
# Out:
# Thresh: 348
# Caitlyn: 426
# Draven: 627
# Kindred: 717
# Veigar: 855
# Rengar: 930
# Vayne: 943
# Singed: 958
# Ivern: 1001
# Evelynn: 1035
# Taliyah: 1103
# Fiddlesticks: 1119
# Annie: 1135
# Heimerdinger: 1146
# Tristana: 1217
# Kled: 1223
# Khazix: 1250
# Kaisa: 1274
# Teemo: 1343
# Karma: 1547
# DrMundo: 1563
# Shaco: 1653
# Poppy: 1667
# Xayah: 1679
# Jinx: 1681
# Jayce: 1681
# Camille: 1682
# Jhin: 1682
# Varus: 1687
# Rammus: 1693
# Sion: 1710
# Lulu: 2599
# Nunu: 3803
# Jax: 3916
# Twitch: 7213

# %% [markdown]
# # Game Stats

# %%
#however many games ago here
hmga = '0'
lastGame = requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/' + puuId + '/ids'+ '?api_key=' + apiKey + '&start=' +hmga + '&count=1')
lg = lastGame.json()[0]
matchData = requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/' + lg + '?api_key=' + apiKey)
md = matchData.json()
md
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_3928694934',
#   'participants': ['Q6Qd5xaKnO3BTQTixRKzukKpkwrSGQETcIhnuOfK87VIaid4rWaIg6S9PVwOeQzAS7HA15aq5i72FQ',
#    '10yu-A_nSFY68KlXxhgND2NOTraa14N8hRMZ2HDlSc143NUgYyICPOqPO7dyUg2LHWPoz_epgREVEw',
#    'bQM9zXt8MH6LAFDxxjCoGeVS6CNjKz6GjJujKpiflkylsxWXm9mchfJwnAjtzgnGnNndXNSaf6dZpg',
#    'NJOmx8gmVYUmxcR0hSVNpkH3Fww__kmoNQ2McFO6gBcjIirgJt1bNB6-K2sxYTVeuvkeJ3huNdEaOg',
#    'Hfr2lYWugol4WzwOzBAxAfEdaWG_Zse39lx4hNbTuBLzH3zR09af9fWx9rQo6A7OGxMjNav1QBcwuw',
#    'LXUUOfftgmLsm79qM1C37oPKGmG7B2P0GNjGBFZ1QYD70btTDwJCW-tdK0mzDYOKZCE3BQRCXWTSiw',
#    'eqtvF9TFm-GZJk_kqNiRj4JlIjLq-yUsi4pdzj7ZSaa5oPiU_2aHpJ5tIyWq4wiqQ_2FYCKMBB5HPg',
#    'OqdOA4ZGVYXkvlLPihPGSDD-vfmh2mHJKEY8XgBm-JdFC8b9EvjWPJakNxgnCMUwRUABKd6ExPXWXw',
#    '1HCsHzQz0f8JhOTJYh1mvB2Mn_CNmQXpJlustiVLPsM0wqDlYHCT-sjI1cCmJOVFD_Gu_0BP9OmpHA',
#    'xZ6VnPfwZUd0huJENQgzFF19WhEQRZ4j2Z6u_GDvTxLlvIH8uFTpr8JAnLyy8z0BBl-gBieVdSDOzg']},
#  'info': {'gameCreation': 1622575854000,
# ...

# %%
gmode = {'CLASSIC': 'Summoner\'s Rift (Normals)','ARAM': 'Howling Abyss (ARAM)'}
gtime = md['info']['gameDuration']
print('Gamemode: ' + gmode[md['info']['gameMode']])
print('Duration: ' + str(gtime//60000) + 'm' + str((gtime-60000*(gtime//60000))//1000) + 's')
# Out:
# Gamemode: Howling Abyss (ARAM)
# Duration: 22m23s

# %%
index = md['metadata']['participants'].index(puuId)
sumStats = md['info']['participants'][index]
sumStats
# Out:
# {'assists': 23,
#  'baronKills': 0,
#  'bountyLevel': 0,
#  'champExperience': 19586,
#  'champLevel': 18,
#  'championId': 20,
#  'championName': 'Nunu',
#  'championTransform': 0,
#  'consumablesPurchased': 0,
#  'damageDealtToBuildings': 0,
#  'damageDealtToObjectives': 0,
#  'damageDealtToTurrets': 0,
#  'damageSelfMitigated': 40240,
#  'deaths': 27,
#  'detectorWardsPlaced': 0,
#  'doubleKills': 2,
#  'dragonKills': 0,
#  'firstBloodAssist': False,
#  'firstBloodKill': False,
#  'firstTowerAssist': False,
#  'firstTowerKill': False,
#  'gameEndedInEarlySurrender': False,
#  'gameEndedInSurrender': False,
#  'goldEarned': 15447,
#  'goldSpent': 14450,
#  'individualPosition': 'Invalid',
#  'inhibitorKills': 0,
#  'inhibitorsLost': 1,
#  'item0': 4636,
#  'item1': 3020,
#  'item2': 3089,
#  'item3': 4629,
#  'item4': 3135,
#  'item5': 1026,
#  'item6': 2052,
#  'itemsPurchased': 20,
#  'killingSprees': 2,
#  'kills': 15,
#  'lane': 'BOTTOM',
#  'largestCriticalStrike': 0,
# ...

# %%
mkconversion = {1:'Single kill',2:'Double kill',3: 'Triple kill',4:'Quadra kill',5:'Pentakill'}
winconversion = {True:'Won',False:'Lost'}

kda = str(sumStats['kills']) + '/' + str(sumStats['deaths']) + '/' + str(sumStats['assists'])
champName = sumStats['championName']
position = sumStats['individualPosition'].lower().title()
largestmk = mkconversion[sumStats['largestMultiKill']]
bint = str(sumStats['totalTimeSpentDead']) + 's (' + '{:.2f}'.format(sumStats['totalTimeSpentDead']/sumStats['timePlayed']*100) + '%)'
win = winconversion[sumStats['win']]

damageDealt = str(sumStats['totalDamageDealtToChampions'])
damageTaken = str(sumStats['totalDamageTaken'])
damageMitigated = str(sumStats['damageSelfMitigated'])
damageToObjectives= str(sumStats['damageDealtToObjectives'])
healing = str(sumStats['totalHeal'])

parti = md['info']['participants']

dD =[]
for player in parti:
    dD.append(player['totalDamageDealtToChampions'])
dD = sorted(dD,reverse=True)
dDr = 'unknown'
for i in range(1,11):
    if dD[i-1] == sumStats['totalDamageDealtToChampions']:
        dDr = str(i)

dT =[]
for player in parti:
    dT.append(player['totalDamageTaken'])
dT = sorted(dT,reverse=True)
dTr = 'unknown'
for i in range(1,11):
    if dT[i-1] == sumStats['totalDamageTaken']:
        dTr = str(i)

dM =[]
for player in parti:
    dM.append(player['damageSelfMitigated'])
dM = sorted(dM,reverse=True)
dMr = 'unknown'
for i in range(1,11):
    if dM[i-1] == sumStats['damageSelfMitigated']:
        dMr = str(i)

dO =[]
for player in parti:
    dO.append(player['damageDealtToObjectives'])
dO = sorted(dO,reverse=True)
dOr = 'unknown'
for i in range(1,11):
    if dO[i-1] == sumStats['damageDealtToObjectives']:
        dOr = str(i)

tH =[]
for player in parti:
    tH.append(player['totalHeal'])
tH = sorted(tH,reverse=True)
tHr = 'unknown'
for i in range(1,11):
    if tH[i-1] == sumStats['totalHeal']:
        tHr = str(i)

# %%
print('Gamemode: ' + gmode[md['info']['gameMode']])
print('Duration: ' + str(gtime//60000) + 'm' + str((gtime-60000*(gtime//60000))//1000) + 's')

print('Outcome: ' + win)
print('Champion: ' + champName)
print('Role: ' + position)
print('KDA: ' + kda)
print('Largest Multikill: ' + largestmk)
print('Time Binting: ' + bint)

print('Damage Dealt: ' + damageDealt + ' (' + dDr + ')')
print('Damage Taken: ' + damageTaken + ' (' + dTr + ')')
print('Damage Mitigated: ' + damageMitigated + ' (' + dMr + ')')
print('Damage to Objectives: ' + damageToObjectives + ' (' + dOr + ')')
print('Healing: ' + healing + ' (' + tHr + ')')
# Out:
# Gamemode: Howling Abyss (ARAM)
# Duration: 22m23s
# Outcome: Lost
# Champion: Nunu
# Role: Invalid
# KDA: 15/27/23
# Largest Multikill: Double kill
# Time Binting: 638s (47.51%)
# Damage Dealt: 33734 (4)
# Damage Taken: 54689 (1)
# Damage Mitigated: 40240 (2)
# Damage to Objectives: 0 (10)
# Healing: 7403 (5)
